# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
import darts

print("="*50)
print("✅ VÉRIFICATION DES LIBRAIRIES")
print("="*50)
print(f"pandas: {pd.__version__}")
print(f"numpy: {np.__version__}")
print(f"PyTorch: {torch.__version__}")
print(f"darts: {darts.__version__}")
print()

# Test GPU M3
if torch.backends.mps.is_available():
    device = torch.device("mps")
    print("🚀 GPU M3 Pro détecté et prêt!")
else:
    device = torch.device("cpu")
    print("💻 Mode CPU")

print()
print("="*50)
print("🎉 ENVIRONNEMENT PRÊT - ON PEUT CODER!")
print("="*50)
# Out:
# ==================================================
# ✅ VÉRIFICATION DES LIBRAIRIES
# ==================================================
# pandas: 2.3.3
# numpy: 2.3.4
# PyTorch: 2.8.0
# darts: 0.38.0
#
# 🚀 GPU M3 Pro détecté et prêt!
#
# ==================================================
# 🎉 ENVIRONNEMENT PRÊT - ON PEUT CODER!
# ==================================================
